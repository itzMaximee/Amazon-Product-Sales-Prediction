# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# %%
df = pd.read_csv("D:/Coding/Python/amazon_products_sales_data_uncleaned.csv")
df
# Out:
#                                                    title              rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
# ...                                                  ...                 ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...  5.0 out of 5 stars
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...  4.2 out of 5 stars
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...  4.3 out of 5 stars
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...  4.7 out of 5 stars
# 42674  Lorex Fusion 1080p HD Security Camera System w...  4.4 out of 5 stars
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  object
#  2   number_of_reviews         41651 non-null  object
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  30926 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  buy_box_availability      28022 non-null  object
#  11  delivery_details          30955 non-null  object
#  12  sustainability_badges     3408 non-null   object
# ...

# %%
df.drop(columns=["image_url"],inplace=True) 
df.drop(columns=["product_url"],inplace=True)

# %%
df
# Out:
#                                                    title              rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
# ...                                                  ...                 ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...  5.0 out of 5 stars
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...  4.2 out of 5 stars
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...  4.3 out of 5 stars
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...  4.7 out of 5 stars
# 42674  Lorex Fusion 1080p HD Security Camera System w...  4.4 out of 5 stars
#
# ...

# %%
df['buy_box_availability'].unique()
# Out:
# array(['Add to cart', nan], dtype=object)

# %%
df = pd.get_dummies(df , columns=['buy_box_availability'], drop_first= True)

# %%
df
# Out:
#                                                    title              rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
# ...                                                  ...                 ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...  5.0 out of 5 stars
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...  4.2 out of 5 stars
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...  4.3 out of 5 stars
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...  4.7 out of 5 stars
# 42674  Lorex Fusion 1080p HD Security Camera System w...  4.4 out of 5 stars
#
# ...

# %%
df['current/discounted_price'] = df['current/discounted_price'].fillna(0)

# %%
df
# Out:
#                                                    title              rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
# ...                                                  ...                 ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...  5.0 out of 5 stars
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...  4.2 out of 5 stars
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...  4.3 out of 5 stars
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...  4.7 out of 5 stars
# 42674  Lorex Fusion 1080p HD Security Camera System w...  4.4 out of 5 stars
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  object
#  2   number_of_reviews         41651 non-null  object
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  42675 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  delivery_details          30955 non-null  object
#  11  sustainability_badges     3408 non-null   object
#  12  collected_at              42675 non-null  object
# dtypes: object(13)
# memory usage: 4.2+ MB

# %%
df['rating'].unique
# Out:
# <bound method Series.unique of 0        4.6 out of 5 stars
# 1        4.3 out of 5 stars
# 2        4.6 out of 5 stars
# 3        4.6 out of 5 stars
# 4        4.8 out of 5 stars
#                 ...
# 42670    5.0 out of 5 stars
# 42671    4.2 out of 5 stars
# 42672    4.3 out of 5 stars
# 42673    4.7 out of 5 stars
# 42674    4.4 out of 5 stars
# Name: rating, Length: 42675, dtype: object>

# %%
df['rating'] = df['rating'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#       number_of_reviews       bought_in_last_month current/discounted_price  \
# 0                   375  300+ bought in past month                    89.68
# ...

# %%
df['title'].unique()
# Out:
# array(['BOYA BOYALINK 2 Wireless Lavalier Microphone for iPhone Camera Android, Mini Lapel Micophone Wireless, 48 KHz 24 Bit, 6mm Mic, 1000ft, 30h Use, Noise Cancelling, Clip on Mic USB-C/Lightning/3.5mm TRS',
#        'LISEN USB C to Lightning Cable, 240W 4 in 1 Charging Cable 6.6FT, Chubby USB A/C to C/Lightning with Light for iPhone 16e 15 14 Pro/MacBook Air 17/iPad/Samsung/Switch 2, Multi Chargers for All Devices',
#        'DJI Mic 2 (2 TX + 1 RX + Charging Case), Wireless Lavalier Microphone, Intelligent Noise Cancelling, 32-bit Float Internal Recording, 820 ft.(250m) Range, Microphone for iPhone, Android, Camera',
#        ...,
#        'Monster Clarity 8.0 Hybrid Active Noise Cancelling Wireless Earbuds, 42dB in-Ear ANC Earphones Deep Bass with 6 Mics, Bluetooth 5.2, 50H Play Time with Wireless Charging Case,Blue',
#        'Audio-Technica HP-EP Replacement Ear Pads for M Series Headphones',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         41651 non-null  object
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  42675 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  delivery_details          30955 non-null  object
#  11  sustainability_badges     3408 non-null   object
#  12  collected_at              42675 non-null  object
# dtypes: float64(1), object(12)
# ...

# %%
df['number_of_reviews'] = df['number_of_reviews'].str.replace(',', '').fillna('0').astype(int)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews       bought_in_last_month current/discounted_price  \
# 0                    375  300+ bought in past month                    89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  42675 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  delivery_details          30955 non-null  object
#  11  sustainability_badges     3408 non-null   object
#  12  collected_at              42675 non-null  object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
df = pd.get_dummies(df , columns=['is_sponsored'], drop_first= True)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews       bought_in_last_month current/discounted_price  \
# 0                    375  300+ bought in past month                    89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  42675 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_couponed               42675 non-null  object
#  9   delivery_details          30955 non-null  object
#  10  sustainability_badges     3408 non-null   object
#  11  collected_at              42675 non-null  object
#  12  is_sponsored_Sponsored    42675 non-null  bool
# ...

# %%
df['current/discounted_price'].unique()
# Out:
# array(['89.68', '9.99', '314.00', ..., '1,579.99', '20.14', '1,252.29'],
#       shape=(2577,), dtype=object)

# %%
df.drop(columns=["price_on_variant"],inplace=True)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews       bought_in_last_month current/discounted_price  \
# 0                    375  300+ bought in past month                    89.68
# ...

# %%
df['bought_in_last_month'] = df['bought_in_last_month'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews  bought_in_last_month current/discounted_price  \
# 0                    375                 300.0                    89.68
# ...

# %%
df['listed_price'] = pd.to_numeric(
    df['listed_price'].str.replace('$', '', regex=False)
                       .str.replace(',', '', regex=False)
                       .replace('No Discount', '0'),
    errors='coerce'
).fillna(0).astype(float)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews  bought_in_last_month current/discounted_price  \
# 0                    375                 300.0                    89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      32233 non-null  float64
#  4   current/discounted_price  42675 non-null  object
#  5   listed_price              42675 non-null  float64
#  6   is_best_seller            42675 non-null  object
#  7   is_couponed               42675 non-null  object
#  8   delivery_details          30955 non-null  object
#  9   sustainability_badges     3408 non-null   object
#  10  collected_at              42675 non-null  object
#  11  is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(3), int64(1), object(7)
# memory usage: 3.6+ MB

# %%
labelencoder = LabelEncoder()
encodeddata = labelencoder.fit_transform(df['is_couponed'])
df['is_couponed'] = encodeddata
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews  bought_in_last_month current/discounted_price  \
# 0                    375                 300.0                    89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      32233 non-null  float64
#  4   current/discounted_price  42675 non-null  object
#  5   listed_price              42675 non-null  float64
#  6   is_best_seller            42675 non-null  object
#  7   is_couponed               42675 non-null  int64
#  8   delivery_details          30955 non-null  object
#  9   sustainability_badges     3408 non-null   object
#  10  collected_at              42675 non-null  object
#  11  is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(3), int64(2), object(6)
# memory usage: 3.6+ MB

# %%
df.columns
# Out:
# Index(['title', 'rating', 'number_of_reviews', 'bought_in_last_month',
#        'current/discounted_price', 'listed_price', 'is_best_seller',
#        'is_couponed', 'delivery_details', 'sustainability_badges',
#        'collected_at', 'is_sponsored_Sponsored'],
#       dtype='object')

# %%
df['current/discounted_price'].unique()
# Out:
# array(['89.68', '9.99', '314.00', ..., '1,579.99', '20.14', '1,252.29'],
#       shape=(2577,), dtype=object)

# %%
df['current/discounted_price'] = df['current/discounted_price'].str.replace(',', '').fillna('0').astype(float)

# %%
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews  bought_in_last_month  current/discounted_price  \
# 0                    375                 300.0                     89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      32233 non-null  float64
#  4   current/discounted_price  42675 non-null  float64
#  5   listed_price              42675 non-null  float64
#  6   is_best_seller            42675 non-null  object
#  7   is_couponed               42675 non-null  int64
#  8   delivery_details          30955 non-null  object
#  9   sustainability_badges     3408 non-null   object
#  10  collected_at              42675 non-null  object
#  11  is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(4), int64(2), object(5)
# memory usage: 3.6+ MB

# %%
df.drop(columns=["delivery_details"],inplace=True)

# %%
df['collected_at'].unique()
# Out:
# array(['2025-08-21 11:14:29', '2025-08-21 11:14:46',
#        '2025-08-21 11:14:47', ..., '2025-08-30 19:55:04',
#        '2025-08-30 19:55:28', '2025-08-30 19:56:33'],
#       shape=(1559,), dtype=object)

# %%
df.drop(columns=["collected_at"],inplace=True)

# %%
labelencoder = LabelEncoder()
encodeddata = labelencoder.fit_transform(df['sustainability_badges'])
df['sustainability_badges'] = encodeddata
df
# Out:
#                                                    title  rating  \
# 0      BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1      LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2      DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3      Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4      Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
# ...                                                  ...     ...
# 42670  Elgato 4K Pro, Internal Capture Card: 8K60 Pas...     5.0
# 42671  Arlo Essential Spotlight Camera, Wireless Secu...     4.2
# 42672  GIGABYTE - AORUS FO32U2-32" QD OLED Gaming Mon...     4.3
# 42673  Monoprice XLR Male to 1/4-Inch TRS Male Cable ...     4.7
# 42674  Lorex Fusion 1080p HD Security Camera System w...     4.4
#
#        number_of_reviews  bought_in_last_month  current/discounted_price  \
# 0                    375                 300.0                     89.68
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  float64
#  2   number_of_reviews         42675 non-null  int64
#  3   bought_in_last_month      32233 non-null  float64
#  4   current/discounted_price  42675 non-null  float64
#  5   listed_price              42675 non-null  float64
#  6   is_best_seller            42675 non-null  object
#  7   is_couponed               42675 non-null  int64
#  8   sustainability_badges     42675 non-null  int64
#  9   is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(4), int64(3), object(2)
# memory usage: 3.0+ MB

# %%
df['title'].unique()
# Out:
# array(['BOYA BOYALINK 2 Wireless Lavalier Microphone for iPhone Camera Android, Mini Lapel Micophone Wireless, 48 KHz 24 Bit, 6mm Mic, 1000ft, 30h Use, Noise Cancelling, Clip on Mic USB-C/Lightning/3.5mm TRS',
#        'LISEN USB C to Lightning Cable, 240W 4 in 1 Charging Cable 6.6FT, Chubby USB A/C to C/Lightning with Light for iPhone 16e 15 14 Pro/MacBook Air 17/iPad/Samsung/Switch 2, Multi Chargers for All Devices',
#        'DJI Mic 2 (2 TX + 1 RX + Charging Case), Wireless Lavalier Microphone, Intelligent Noise Cancelling, 32-bit Float Internal Recording, 820 ft.(250m) Range, Microphone for iPhone, Android, Camera',
#        ...,
#        'Monster Clarity 8.0 Hybrid Active Noise Cancelling Wireless Earbuds, 42dB in-Ear ANC Earphones Deep Bass with 6 Mics, Bluetooth 5.2, 50H Play Time with Wireless Charging Case,Blue',
#        'Audio-Technica HP-EP Replacement Ear Pads for M Series Headphones',
# ...

# %%
df["is_best_seller"] = df["is_best_seller"].apply(lambda x: 1 if x == "Best Seller" else 0)

# %%
df.drop(columns=["title"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rating                    41651 non-null  float64
#  1   number_of_reviews         42675 non-null  int64
#  2   bought_in_last_month      32233 non-null  float64
#  3   current/discounted_price  42675 non-null  float64
#  4   listed_price              42675 non-null  float64
#  5   is_best_seller            42675 non-null  int64
#  6   is_couponed               42675 non-null  int64
#  7   sustainability_badges     42675 non-null  int64
#  8   is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(4), int64(4)
# memory usage: 2.6 MB

# %%
df.isna().sum()
# Out:
# rating                       1024
# number_of_reviews               0
# bought_in_last_month        10442
# current/discounted_price        0
# listed_price                    0
# is_best_seller                  0
# is_couponed                     0
# sustainability_badges           0
# is_sponsored_Sponsored          0
# dtype: int64

# %%
df_noNulls=df.dropna(axis=0)

# %%
df_noNulls.isna().sum()
# Out:
# rating                      0
# number_of_reviews           0
# bought_in_last_month        0
# current/discounted_price    0
# listed_price                0
# is_best_seller              0
# is_couponed                 0
# sustainability_badges       0
# is_sponsored_Sponsored      0
# dtype: int64

# %%
df['rating'].fillna(df['rating'].mode()[0] , inplace=True)
df['bought_in_last_month'].fillna(df['bought_in_last_month'].mode()[0] , inplace=True)
# Out:
# C:\Users\me067\AppData\Local\Temp\ipykernel_21268\3145602379.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].mode()[0] , inplace=True)
# C:\Users\me067\AppData\Local\Temp\ipykernel_21268\3145602379.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isna().sum()
# Out:
# rating                      0
# number_of_reviews           0
# bought_in_last_month        0
# current/discounted_price    0
# listed_price                0
# is_best_seller              0
# is_couponed                 0
# sustainability_badges       0
# is_sponsored_Sponsored      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rating                    42675 non-null  float64
#  1   number_of_reviews         42675 non-null  int64
#  2   bought_in_last_month      42675 non-null  float64
#  3   current/discounted_price  42675 non-null  float64
#  4   listed_price              42675 non-null  float64
#  5   is_best_seller            42675 non-null  int64
#  6   is_couponed               42675 non-null  int64
#  7   sustainability_badges     42675 non-null  int64
#  8   is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(4), int64(4)
# memory usage: 2.6 MB

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42, stratify=df["is_best_seller"])
train, val = train_test_split(train, test_size=0.2, random_state=42, stratify=train["is_best_seller"])
x_train = train[["listed_price"]]
x_val = val[["listed_price"]]
x_test = test[["listed_price"]]
y_train = train["is_best_seller"]
y_val = val["is_best_seller"]
y_test = test["is_best_seller"]

# %%
standard_scaler = StandardScaler()
x_test=standard_scaler.fit_transform(x_test)
x_train=standard_scaler.fit_transform(x_train)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
knn = KNeighborsClassifier()
knn.fit(x_train , y_train)
# Out:
# KNeighborsClassifier()

# %%
lr.score(x_test, y_test)
# Out:
# 0.9935559461042766

# %%
knn.score(x_test, y_test)
# Out:
# 0.9925014645577036

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rating                    42675 non-null  float64
#  1   number_of_reviews         42675 non-null  int64
#  2   bought_in_last_month      42675 non-null  float64
#  3   current/discounted_price  42675 non-null  float64
#  4   listed_price              42675 non-null  float64
#  5   is_best_seller            42675 non-null  int64
#  6   is_couponed               42675 non-null  int64
#  7   sustainability_badges     42675 non-null  int64
#  8   is_sponsored_Sponsored    42675 non-null  bool
# dtypes: bool(1), float64(4), int64(4)
# memory usage: 2.6 MB
